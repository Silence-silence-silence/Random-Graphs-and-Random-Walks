# %%
library(igraph)
library(resample)
library(textTinyR)
library(Matrix)
library(pracma)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bb052d26e00a> in <cell line: 1>()
# ----> 1 library(igraph)
#       2 library(resample)
#       3 library(textTinyR)
#       4 library(Matrix)
#       5 library(pracma)
#
# NameError: name 'library' is not defined
